# %% [markdown]
# # Analyse: comparison between small intestine cells and  fetal small intestine

# %%
from tfcomb import CombObj
genome_path="../testdaten/hg19_masked.fa"
motif_path="../testdaten/HOCOMOCOv11_HUMAN_motifs.txt"
result_path="./results/"

# %% [markdown]
# Using saved objects from market basket analysis from pkl files for liver and hepG2 cells using complete results of TF. Saving results from market basket analysis in objects.

# %%
fetal_small_instestine_object= CombObj().from_pickle(f"{result_path}Fetal_small_intestine_enhancers_complete.pkl")
fetal_small_instestine_object.prefix = "fetal small instestine"

small_instestine_object = CombObj().from_pickle(f"{result_path}Small_intestine_enhancers_complete.pkl")
small_instestine_object.prefix = "small instestine"

# %% [markdown]
# Showing found rules of TF in each cell line

# %%
print(f"fetal small instestine: {fetal_small_instestine_object}")
print(f"samll instestine: {small_instestine_object}")
# Out:
# fetal small instestine: <CombObj: 1041640 TFBS (401 unique names) | Market basket analysis: 160785 rules>
# samll instestine: <CombObj: 680162 TFBS (401 unique names) | Market basket analysis: 160752 rules>

# %% [markdown]
# Comparing rules of TF of cell line objects

# %%
compare_obj_fetal_small_instestine_small_instestine = fetal_small_instestine_object.compare(small_instestine_object)
# Out:
# INFO: Calculating foldchange for contrast: fetal small instestine / small instestine
# INFO: The calculated log2fc's are found in the rules table (<DiffCombObj>.rules)

# %% [markdown]
# ## Results Differential analysis of fetal small intestine and small intestine cells

# %% [markdown]
# Results of differential analysis are found in compare_obj_fetal_small_instestine_small_instestine. The table shows the rules of TF that distinguish strongly in occurence. The duplicates in the results are removed with simplify rules

# %%
compare_obj_fetal_small_instestine_small_instestine.simplify_rules()
compare_obj_fetal_small_instestine_small_instestine.rules
# Out:
#                 TF1    TF2  fetal small instestine_cosine  \
# ZNF549-LHX3  ZNF549   LHX3                       0.042553
# CREB1-ATF1    CREB1   ATF1                       0.051641
# ATF1-PAX5      ATF1   PAX5                       0.028917
# RFX1-CREB1     RFX1  CREB1                       0.026016
# CREB1-CREM    CREB1   CREM                       0.032934
# ...             ...    ...                            ...
# HOXB4-NOBOX   HOXB4  NOBOX                       0.052528
# ZNF214-TFE3  ZNF214   TFE3                       0.039557
# DLX3-CEBPD     DLX3  CEBPD                       0.039505
# MECP2-MECP2   MECP2  MECP2                       0.111922
# MECP2-NR2C2   MECP2  NR2C2                       0.167819
#
#              small instestine_cosine  \
# ZNF549-LHX3                 0.101723
# CREB1-ATF1                  0.111009
# ATF1-PAX5                   0.069663
# RFX1-CREB1                  0.064735
# CREB1-CREM                  0.074569
# ...                              ...
# HOXB4-NOBOX                 0.024219
# ZNF214-TFE3                 0.014523
# DLX3-CEBPD                  0.013126
# MECP2-MECP2                 0.058438
# MECP2-NR2C2                 0.076455
#
#              fetal small instestine/small instestine_cosine_log2fc  \
# ZNF549-LHX3                                          -0.760059
# CREB1-ATF1                                           -0.703885
# ATF1-PAX5                                            -0.649361
# RFX1-CREB1                                           -0.644282
# CREB1-CREM                                           -0.632319
# ...                                                        ...
# HOXB4-NOBOX                                           0.508597
# ZNF214-TFE3                                           0.523078
# DLX3-CEBPD                                            0.557796
# MECP2-MECP2                                           0.612123
# MECP2-NR2C2                                           0.820797
#
#              fetal small instestine/small instestine_cosine_log2fc_pvalue  \
# ZNF549-LHX3                                       2.719494e-19
# CREB1-ATF1                                        0.000000e+00
# ATF1-PAX5                                         0.000000e+00
# RFX1-CREB1                                        0.000000e+00
# CREB1-CREM                                        0.000000e+00
# ...                                                        ...
# HOXB4-NOBOX                                       2.311804e-05
# ZNF214-TFE3                                       2.729543e-06
# DLX3-CEBPD                                        5.052811e-06
# MECP2-MECP2                                       0.000000e+00
# MECP2-NR2C2                                       0.000000e+00
#
#              fetal small instestine/small instestine_cosine_log2fc_pvalue_adj
# ZNF549-LHX3                                       4.371423e-14
# CREB1-ATF1                                        0.000000e+00
# ATF1-PAX5                                         0.000000e+00
# RFX1-CREB1                                        0.000000e+00
# CREB1-CREM                                        0.000000e+00
# ...                                                        ...
# HOXB4-NOBOX                                       1.000000e+00
# ZNF214-TFE3                                       4.387576e-01
# DLX3-CEBPD                                        8.122091e-01
# MECP2-MECP2                                       0.000000e+00
# MECP2-NR2C2                                       0.000000e+00
#
# [80572 rows x 7 columns]

# %%
compare_obj_fetal_small_instestine_small_instestine.plot_heatmap()

# %%
selection_fetal_small_instestine_small_instestine= compare_obj_fetal_small_instestine_small_instestine.select_rules(measure_threshold_percent=0.0002)
# Out:
# INFO: Selecting rules for contrast: ('fetal small instestine', 'small instestine')
# INFO: measure_threshold is None; trying to calculate optimal threshold
# INFO: Creating subset of rules using thresholds

# %%
selection_fetal_small_instestine_small_instestine.plot_network()
# Out:
# INFO: Finished! The network is found within <CombObj>.network.

# %%
selection_fetal_small_instestine_small_instestine.rules.head(10)
# Out:
#                   TF1     TF2  fetal small instestine_cosine  \
# ZNF549-LHX3    ZNF549    LHX3                       0.042553
# CREB1-ATF1      CREB1    ATF1                       0.051641
# ATF1-PAX5        ATF1    PAX5                       0.028917
# RFX1-CREB1       RFX1   CREB1                       0.026016
# CREB1-CREM      CREB1    CREM                       0.032934
# ZNF549-ZNF549  ZNF549  ZNF549                       0.024086
# ATF1-RFX1        ATF1    RFX1                       0.036158
# PAX5-CREB1       PAX5   CREB1                       0.027798
# CREB1-ATF2      CREB1    ATF2                       0.030331
# CREB1-CREB1     CREB1   CREB1                       0.026093
#
#                small instestine_cosine  \
# ZNF549-LHX3                   0.101723
# CREB1-ATF1                    0.111009
# ATF1-PAX5                     0.069663
# RFX1-CREB1                    0.064735
# CREB1-CREM                    0.074569
# ZNF549-ZNF549                 0.059985
# ATF1-RFX1                     0.077711
# PAX5-CREB1                    0.063790
# CREB1-ATF2                    0.065708
# CREB1-CREB1                   0.059386
#
#                fetal small instestine/small instestine_cosine_log2fc  \
# ZNF549-LHX3                                            -0.760059
# CREB1-ATF1                                             -0.703885
# ATF1-PAX5                                              -0.649361
# RFX1-CREB1                                             -0.644282
# CREB1-CREM                                             -0.632319
# ZNF549-ZNF549                                          -0.620148
# ATF1-RFX1                                              -0.610261
# PAX5-CREB1                                             -0.594647
# CREB1-ATF2                                             -0.569507
# CREB1-CREB1                                            -0.569046
#
#                fetal small instestine/small instestine_cosine_log2fc_pvalue  \
# ZNF549-LHX3                                         2.719494e-19
# CREB1-ATF1                                          0.000000e+00
# ATF1-PAX5                                           0.000000e+00
# RFX1-CREB1                                          0.000000e+00
# CREB1-CREM                                          0.000000e+00
# ZNF549-ZNF549                                       0.000000e+00
# ATF1-RFX1                                           0.000000e+00
# PAX5-CREB1                                          0.000000e+00
# CREB1-ATF2                                          0.000000e+00
# CREB1-CREB1                                         0.000000e+00
#
#                fetal small instestine/small instestine_cosine_log2fc_pvalue_adj
# ZNF549-LHX3                                         4.371423e-14
# CREB1-ATF1                                          0.000000e+00
# ATF1-PAX5                                           0.000000e+00
# RFX1-CREB1                                          0.000000e+00
# CREB1-CREM                                          0.000000e+00
# ZNF549-ZNF549                                       0.000000e+00
# ATF1-RFX1                                           0.000000e+00
# PAX5-CREB1                                          0.000000e+00
# CREB1-ATF2                                          0.000000e+00
# CREB1-CREB1                                         0.000000e+00

# %%
selection_fetal_small_instestine_small_instestine.rules.tail(10)
# Out:
#                  TF1     TF2  fetal small instestine_cosine  \
# CUX1-POU2F2     CUX1  POU2F2                       0.030277
# MTF1-HINFP      MTF1   HINFP                       0.025538
# PRRX2-RFX3     PRRX2    RFX3                       0.037236
# TFE3-HOXC9      TFE3   HOXC9                       0.042072
# PRRX2-TCF7L2   PRRX2  TCF7L2                       0.051807
# HOXB4-NOBOX    HOXB4   NOBOX                       0.052528
# ZNF214-TFE3   ZNF214    TFE3                       0.039557
# DLX3-CEBPD      DLX3   CEBPD                       0.039505
# MECP2-MECP2    MECP2   MECP2                       0.111922
# MECP2-NR2C2    MECP2   NR2C2                       0.167819
#
#               small instestine_cosine  \
# CUX1-POU2F2                  0.010526
# MTF1-HINFP                   0.006895
# PRRX2-RFX3                   0.014529
# TFE3-HOXC9                   0.017657
# PRRX2-TCF7L2                 0.024542
# HOXB4-NOBOX                  0.024219
# ZNF214-TFE3                  0.014523
# DLX3-CEBPD                   0.013126
# MECP2-MECP2                  0.058438
# MECP2-NR2C2                  0.076455
#
#               fetal small instestine/small instestine_cosine_log2fc  \
# CUX1-POU2F2                                            0.454879
# MTF1-HINFP                                             0.459895
# PRRX2-RFX3                                             0.481667
# TFE3-HOXC9                                             0.489655
# PRRX2-TCF7L2                                           0.490701
# HOXB4-NOBOX                                            0.508597
# ZNF214-TFE3                                            0.523078
# DLX3-CEBPD                                             0.557796
# MECP2-MECP2                                            0.612123
# MECP2-NR2C2                                            0.820797
#
#               fetal small instestine/small instestine_cosine_log2fc_pvalue  \
# CUX1-POU2F2                                        1.600227e-07
# MTF1-HINFP                                         0.000000e+00
# PRRX2-RFX3                                         5.513864e-04
# TFE3-HOXC9                                         1.798802e-04
# PRRX2-TCF7L2                                       1.137794e-04
# HOXB4-NOBOX                                        2.311804e-05
# ZNF214-TFE3                                        2.729543e-06
# DLX3-CEBPD                                         5.052811e-06
# MECP2-MECP2                                        0.000000e+00
# MECP2-NR2C2                                        0.000000e+00
#
#               fetal small instestine/small instestine_cosine_log2fc_pvalue_adj
# CUX1-POU2F2                                            0.025723
# MTF1-HINFP                                             0.000000
# PRRX2-RFX3                                             1.000000
# TFE3-HOXC9                                             1.000000
# PRRX2-TCF7L2                                           1.000000
# HOXB4-NOBOX                                            1.000000
# ZNF214-TFE3                                            0.438758
# DLX3-CEBPD                                             0.812209
# MECP2-MECP2                                            0.000000
# MECP2-NR2C2                                            0.000000

# %% [markdown]
# ## Biological meaning
